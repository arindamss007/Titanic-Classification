# %% [markdown]
# ## **TITANIC CLASSIFICATION**

# %% [markdown]
# **Variable Notes**
#
# pclass: A proxy for socio-economic status (SES)
# 1st = Upper
# 2nd = Middle
# 3rd = Lower
#
# age: Age is fractional if less than 1. If the age is estimated, is it in the form of xx.5
#
# sibsp: The dataset defines family relations in this way...
# Sibling = brother, sister, stepbrother, stepsister
# Spouse = husband, wife (mistresses and fiancés were ignored)
#
# parch: The dataset defines family relations in this way...
# Parent = mother, father
# Child = daughter, son, stepdaughter, stepson
# Some children travelled only with a nanny, therefore parch=0 for them.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Datasets/Titanic Classification/train.csv')

df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.isnull().sum() #Detecting Missing Values
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
sns.countplot(x=df['Embarked']) #Visualization of Embarked Series
# Out:
# <Axes: xlabel='Embarked', ylabel='count'>

# %% [markdown]
# **DATA CLEANING**

# %%
age_Mean = df['Age'].mean()
df['Age'].fillna(age_Mean, inplace=True)
df['Embarked'].fillna('S', inplace=True)

df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# ...

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          891 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     891 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
sns.countplot(x='Survived', data=df) # Survival Visualization
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
sns.countplot(x='Sex', hue='Survived', data=df) # Gender-wise Survival
# Out:
# <Axes: xlabel='Sex', ylabel='count'>

# %%
sns.countplot(x='Pclass', hue='Survived', data=df) # Passenger Class-wise Survival
# Out:
# <Axes: xlabel='Pclass', ylabel='count'>

# %%
unwanted = ['Cabin', 'PassengerId', 'Name', 'Ticket']
titanic_df = df.drop(unwanted, axis=1)
titanic_df
# Out:
#      Survived  Pclass     Sex        Age  SibSp  Parch     Fare Embarked
# 0           0       3    male  22.000000      1      0   7.2500        S
# 1           1       1  female  38.000000      1      0  71.2833        C
# 2           1       3  female  26.000000      0      0   7.9250        S
# 3           1       1  female  35.000000      1      0  53.1000        S
# 4           0       3    male  35.000000      0      0   8.0500        S
# ..        ...     ...     ...        ...    ...    ...      ...      ...
# 886         0       2    male  27.000000      0      0  13.0000        S
# 887         1       1  female  19.000000      0      0  30.0000        S
# 888         0       3  female  29.699118      1      2  23.4500        S
# 889         1       1    male  26.000000      0      0  30.0000        C
# 890         0       3    male  32.000000      0      0   7.7500        Q
#
# [891 rows x 8 columns]

# %% [markdown]
# **CLEANING UNWANTED COLUMNS**

# %%
d = {'male':0, 'female':1}
titanic_df['Sex'] = titanic_df['Sex'].map(d)

titanic_df
# Out:
#      Survived  Pclass  Sex        Age  SibSp  Parch     Fare Embarked
# 0           0       3    0  22.000000      1      0   7.2500        S
# 1           1       1    1  38.000000      1      0  71.2833        C
# 2           1       3    1  26.000000      0      0   7.9250        S
# 3           1       1    1  35.000000      1      0  53.1000        S
# 4           0       3    0  35.000000      0      0   8.0500        S
# ..        ...     ...  ...        ...    ...    ...      ...      ...
# 886         0       2    0  27.000000      0      0  13.0000        S
# 887         1       1    1  19.000000      0      0  30.0000        S
# 888         0       3    1  29.699118      1      2  23.4500        S
# 889         1       1    0  26.000000      0      0  30.0000        C
# 890         0       3    0  32.000000      0      0   7.7500        Q
#
# [891 rows x 8 columns]

# %% [markdown]
# **COLUMN MAPPING FOR HIGH DATA RELATION**

# %%
d = {'S':1,'C':2,'Q':3 }
titanic_df['Embarked'] = titanic_df['Embarked'].map(d)

titanic_df
# Out:
#      Survived  Pclass  Sex        Age  SibSp  Parch     Fare  Embarked
# 0           0       3    0  22.000000      1      0   7.2500         1
# 1           1       1    1  38.000000      1      0  71.2833         2
# 2           1       3    1  26.000000      0      0   7.9250         1
# 3           1       1    1  35.000000      1      0  53.1000         1
# 4           0       3    0  35.000000      0      0   8.0500         1
# ..        ...     ...  ...        ...    ...    ...      ...       ...
# 886         0       2    0  27.000000      0      0  13.0000         1
# 887         1       1    1  19.000000      0      0  30.0000         1
# 888         0       3    1  29.699118      1      2  23.4500         1
# 889         1       1    0  26.000000      0      0  30.0000         2
# 890         0       3    0  32.000000      0      0   7.7500         3
#
# [891 rows x 8 columns]

# %%
sns.countplot(x='Parch', data=df) # Parch Visualization
# Out:
# <Axes: xlabel='Parch', ylabel='count'>

# %%
sns.countplot(x='SibSp', data=df) # Siblings Count Visualiztion
# Out:
# <Axes: xlabel='SibSp', ylabel='count'>

# %%
titanic_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Sex       891 non-null    int64
#  3   Age       891 non-null    float64
#  4   SibSp     891 non-null    int64
#  5   Parch     891 non-null    int64
#  6   Fare      891 non-null    float64
#  7   Embarked  891 non-null    int64
# dtypes: float64(2), int64(6)
# memory usage: 55.8 KB

# %%
sns.heatmap(titanic_df.corr(), annot=True) #Column Correlation
# Out:
# <Axes: >

# %% [markdown]
# **FEATURE EXTRACTION**

# %%
features = [
            'Pclass',
            'Sex',
            'Age',
            'SibSp',
            'Parch',
            'Fare',
            'Embarked']

X = titanic_df[features]
y = titanic_df.Survived

# %% [markdown]
# **MODEL TRAINING**

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import SGDClassifier, LogisticRegression
from sklearn.svm import SVC, LinearSVC
import sklearn.metrics
from sklearn.metrics import confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, r2_score


x_train, x_valid, y_train, y_valid = train_test_split(X, y, train_size=0.80)

models = [ DecisionTreeClassifier(max_depth=15, max_features=13, random_state=42),
           RandomForestClassifier(max_depth=15),
           SGDClassifier(max_iter=500, random_state=42),
           SVC(max_iter=500, random_state=42),
           LogisticRegression(max_iter=1000, random_state=42)
           ]
modelname =['DecisionTree Classifier', 'RandomForest Classifier', 'SGDClassifier', 'Support Vector Class', 'Logistic Regression']

# %% [markdown]
# **MODEL EXECUTION**

# %%
i=0
for model in models :
  print(f'{modelname[i]} Algorithm Report : \n')
  i = i+1
  titanic = model.fit(x_train, y_train)
  preds = titanic.predict(x_valid)
  print(f'Mean Absolute Error : {mean_absolute_error(y_valid, preds)}')
  print(f'Accuracy Score : {r2_score(y_valid, preds)}')
  print("\n")
# Out:
# DecisionTree Classifier Algorithm Report :
#
# Mean Absolute Error : 0.19553072625698323
# Accuracy Score : 0.1651119402985073
#
#
# RandomForest Classifier Algorithm Report :
#
# Mean Absolute Error : 0.13966480446927373
# Accuracy Score : 0.40365138592750516
#
#
# SGDClassifier Algorithm Report :
#
# Mean Absolute Error : 0.6312849162011173
# Accuracy Score : -1.6954957356076767
#
#
# Support Vector Class Algorithm Report :
#
# Mean Absolute Error : 0.3240223463687151
# Accuracy Score : -0.38352878464818807
#
#
# Logistic Regression Algorithm Report :
#
# Mean Absolute Error : 0.16201117318435754
# Accuracy Score : 0.30823560767590596

# %% [markdown]
# **CONFUSION MATRIX REPORT**

# %%
i=0

for model in models :
    print(f'{modelname[i]} Report : ')
    i=i+1
    model.fit(x_train, y_train)
    preds = model.predict(x_valid)
    cm = confusion_matrix(y_valid, preds)
    sns.heatmap(cm, annot=True)
    plt.title("Confusion Matrix")
    plt.xlabel('Predicted')
    plt.ylabel('Actual')
    plt.show()
# Out:
# DecisionTree Classifier Report :
# RandomForest Classifier Report :
# SGDClassifier Report :
# Support Vector Class Report :
# Logistic Regression Report :

# %% [markdown]
# Dataset Link : https://www.kaggle.com/competitions/titanic/data
